# %%
from keras.models import Sequential, load_model
"""Import from keras_preprocessing not from keras.preprocessing, because Keras may or maynot contain the features discussed here depending upon when you read this article, until the keras_preprocessed library is updated in Keras use the github version."""
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split


import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# function to add extension to "id column"
def append_ext(fn):
    return fn+".jpg"

# %%
# read training dataframe provided with labels
train_df = pd.read_csv("labels/labels.csv")
train_df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# read submission test dataframe
test_df = pd.read_csv("sample submission/sample_submission.csv")
test_df.head()
# Out:
#                                  id  affenpinscher  afghan_hound  \
# 0  000621fb3cbb32d8935728e48679680e       0.008333      0.008333
# 1  00102ee9d8eb90812350685311fe5890       0.008333      0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce       0.008333      0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1       0.008333      0.008333
# 4  001a5f3114548acdefa3d4da05474c2e       0.008333      0.008333
#
#    african_hunting_dog  airedale  american_staffordshire_terrier  appenzeller  \
# 0             0.008333  0.008333                        0.008333     0.008333
# 1             0.008333  0.008333                        0.008333     0.008333
# 2             0.008333  0.008333                        0.008333     0.008333
# 3             0.008333  0.008333                        0.008333     0.008333
# 4             0.008333  0.008333                        0.008333     0.008333
#
#    australian_terrier   basenji    basset        ...          toy_poodle  \
# ...

# %%
# apply extensions to train_df and test_df
train_df["id"]=train_df["id"].apply(append_ext)
test_df["id"]=test_df["id"].apply(append_ext)

# %%
# validate "id" column .jpg extension was added
train_df.head()
# Out:
#                                      id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07.jpg       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97.jpg             dingo
# 2  001cdf01b096e06d78e9e5112d419397.jpg          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d.jpg          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62.jpg  golden_retriever

# %%
# Groupby breeds and count the number of images per breed 
# we have in our training set
train_df_sorted = train_df.groupby(train_df["breed"]).count()

# %%
# sort by highest represented breeds
train_df_sorted = train_df_sorted.sort_values(by=["id"], ascending=False)
train_df_sorted.head(8)
# Out:
#                        id
# breed
# scottish_deerhound    126
# maltese_dog           117
# afghan_hound          116
# entlebucher           115
# bernese_mountain_dog  114
# shih-tzu              112
# great_pyrenees        111
# pomeranian            111

# %%
train_df.nunique()
# Out:
# id       10222
# breed      120
# dtype: int64

# %%
# validate "id" column .jpg extension was added
test_df.head()
# Out:
#                                      id  affenpinscher  afghan_hound  \
# 0  000621fb3cbb32d8935728e48679680e.jpg       0.008333      0.008333
# 1  00102ee9d8eb90812350685311fe5890.jpg       0.008333      0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce.jpg       0.008333      0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1.jpg       0.008333      0.008333
# 4  001a5f3114548acdefa3d4da05474c2e.jpg       0.008333      0.008333
#
#    african_hunting_dog  airedale  american_staffordshire_terrier  appenzeller  \
# 0             0.008333  0.008333                        0.008333     0.008333
# 1             0.008333  0.008333                        0.008333     0.008333
# 2             0.008333  0.008333                        0.008333     0.008333
# 3             0.008333  0.008333                        0.008333     0.008333
# 4             0.008333  0.008333                        0.008333     0.008333
#
#    australian_terrier   basenji    basset        ...          toy_poodle  \
# ...
